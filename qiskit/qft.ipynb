# %%
from qft import QFT
from utils import density_matrix_pretty_print

# %%
total_nr_qubits = 4

# %%
qft = QFT(total_nr_qubits, final_swaps=True)

# %%
display(qft.circuit_diagram())

# %%
input = 3

# %%
qft.run(input)

# %%
display(qft.circuit_diagram(with_input=True))

# %%
qft.statevector_latex()
# Out:
# $\displaystyle
# \begin{bmatrix}
# \tfrac{1}{4} \\
# \tfrac{1}{4} \\
# \tfrac{1}{4} \\
# \tfrac{1}{4} \\
# \tfrac{1}{4} \\
# \tfrac{1}{4} \\
# \tfrac{1}{4} \\
# \tfrac{1}{4} \\
# \tfrac{1}{4} \\
# \tfrac{1}{4} \\
# \tfrac{1}{4} \\
# \tfrac{1}{4} \\
# \tfrac{1}{4} \\
# \tfrac{1}{4} \\
# \tfrac{1}{4} \\
# \tfrac{1}{4}
# \end{bmatrix}
# $

# %%
qft.bloch_multivector()

# %%
density_matrix_pretty_print(qft.density_matrix())
# Out:
#  0.063  0.000j     0.063  0.000j     0.063  0.000j     0.063  0.000j     0.063  0.000j     0.063  0.000j     0.063  0.000j     0.062  0.000j     0.063  0.000j     0.063  0.000j     0.063  0.000j     0.062  0.000j     0.063  0.000j     0.062  0.000j     0.062  0.000j     0.062  0.000j
#  0.063  0.000j     0.063  0.000j     0.063  0.000j     0.063  0.000j     0.063  0.000j     0.063  0.000j     0.063  0.000j     0.062  0.000j     0.063  0.000j     0.063  0.000j     0.063  0.000j     0.062  0.000j     0.063  0.000j     0.062  0.000j     0.062  0.000j     0.062  0.000j
#  0.063  0.000j     0.063  0.000j     0.063  0.000j     0.063  0.000j     0.063  0.000j     0.063  0.000j     0.063  0.000j     0.062  0.000j     0.063  0.000j     0.063  0.000j     0.063  0.000j     0.062  0.000j     0.063  0.000j     0.062  0.000j     0.062  0.000j     0.062  0.000j
# ...

# %%
qft.density_matrix_city()
