# %%
from quantum_computer import Method
from distributed_qft import DistributedQFT
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from cluster import Method
#       2 from distributed_qft import DistributedQFT
#
# ModuleNotFoundError: No module named 'cluster'

# %%
nr_processors = 2
total_nr_qubits = 2

# %%
qft = DistributedQFT(nr_processors, total_nr_qubits, Method.CAT_STATE)

# %%
display(qft.circuit_diagram())
