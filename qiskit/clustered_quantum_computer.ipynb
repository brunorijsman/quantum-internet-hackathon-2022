# %%
from quantum_computer import ClusteredQuantumComputer, Method
from examples import EntanglementExampleCluster, TeleportExampleCluster, LocalControlledPhaseExampleCluster
from utils import density_matrix_pretty_print
from numpy import pi

# %% [markdown]
# Create a clustered quantum computer with a total of four main qubits, spread out
# over two processors (i.e. two main qubits per processor):

# %%
nr_processors = 2
total_nr_qubits = 4
method = Method.TELEPORT
computer = ClusteredQuantumComputer(nr_processors, total_nr_qubits, method)
display(computer.circuit_diagram())

# %%
computer = ClusteredQuantumComputer(nr_processors=2, total_nr_qubits=4, method=Method.CAT_STATE)
computer.controlled_phase(pi/4, 0, 3)
computer.circuit_diagram()

# %%
example = LocalControlledPhaseExampleCluster()
display(example.circuit_diagram())

# %%
example = EntanglementExampleCluster()
display(example.circuit_diagram())

# %%
example = TeleportExampleCluster()
display(example.circuit_diagram())
