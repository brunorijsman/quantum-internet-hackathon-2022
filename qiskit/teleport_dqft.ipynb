# %%
from teleport_dqft import TeleportDQFT
from utils import density_matrix_pretty_print

# %%
nr_processors = 2
total_nr_qubits = 2

# %%
qft = TeleportDQFT(nr_processors, total_nr_qubits)

# %%
display(qft.circuit_diagram())
# Out:
#                                                                        »
#         alice_main: ──X────────────────────────────────────────────────»
#                       │                 ┌───┐┌─┐                       »
#     alice_teleport: ──X──────────────■──┤ H ├┤M├───────────────────────»
#                          ┌───┐     ┌─┴─┐└┬─┬┘└╥┘                       »
# alice_entanglement: ─|0>─┤ H ├──■──┤ X ├─┤M├──╫───────────|0>──────────»
#                     ┌───┐└───┘  │  └───┘ └╥┘  ║                        »
#           bob_main: ┤ H ├───────┼─────────╫───╫────────────────────────»
#                     └───┘       │         ║   ║                        »
#       bob_teleport: ────────────┼─────────╫───╫────────────────────────»
#                               ┌─┴─┐       ║   ║          ┌───┐         »
#   bob_entanglement: ─|0>──────┤ X ├───────╫───╫──────────┤ X ├─────────»
#                               └───┘       ║   ║          └─╥─┘         »
#                                           ║   ║ ┌──────────╨──────────┐»
#    alice_measure: 2/══════════════════════╩═══╩═╡ alice_measure_1=0x1 ╞»
#                                           1   0 └─────────────────────┘»
#      bob_measure: 2/═══════════════════════════════════════════════════»
#                                                                        »
# «                                                                              »
# «        alice_main: ──────────────────────────────────────────────────────────»
# «                                                                              »
# «    alice_teleport: ──────────────────────────────────────────────────────────»
# «                                                            ┌───┐             »
# «alice_entanglement: ────────────────────────────────────────┤ X ├─────────────»
# «                                                            └─┬─┘             »
# «          bob_main: ───────────────────────────■──────────────┼───────────────»
# «                                               │P(π/2)        │       ┌───┐┌─┐»
# «      bob_teleport: ────────────────────────X──■──────────────┼────■──┤ H ├┤M├»
# «                             ┌───┐          │          ┌───┐  │  ┌─┴─┐└┬─┬┘└╥┘»
# «  bob_entanglement: ─────────┤ Z ├──────────X────|0>───┤ H ├──■──┤ X ├─┤M├──╫─»
# «                             └─╥─┘                     └───┘     └───┘ └╥┘  ║ »
# «                    ┌──────────╨──────────┐                             ║   ║ »
# «   alice_measure: 2/╡ alice_measure_0=0x1 ╞═════════════════════════════╬═══╬═»
# «                    └─────────────────────┘                             ║   ║ »
# «     bob_measure: 2/════════════════════════════════════════════════════╩═══╩═»
# «                                                                        1   0 »
# «                                                                           »
# «        alice_main: ────────────────────────────────────────────────────X──»
# «                                                                        │  »
# «    alice_teleport: ────────────────────────────────────────────────X───X──»
# «                            ┌───┐                     ┌───┐         │      »
# «alice_entanglement: ────────┤ X ├─────────────────────┤ Z ├─────────X──|0>─»
# «                            └─╥─┘                     └─╥─┘                »
# «          bob_main: ──────────╫─────────────────────────╫──────────────────»
# «                              ║                         ║                  »
# «      bob_teleport: ──────────╫─────────────────────────╫──────────────────»
# «                              ║                         ║                  »
# «  bob_entanglement: ──────────╫───────────|0>───────────╫──────────────────»
# «                              ║                         ║                  »
# «   alice_measure: 2/══════════╬═════════════════════════╬══════════════════»
# «                    ┌─────────╨─────────┐     ┌─────────╨─────────┐        »
# «     bob_measure: 2/╡ bob_measure_1=0x1 ╞═════╡ bob_measure_0=0x1 ╞════════»
# «                    └───────────────────┘     └───────────────────┘        »
# «                    ┌───┐                                         »
# «        alice_main: ┤ H ├──X──────────────────────────────────────»
# «                    └───┘  │       ┌───┐┌─┐                       »
# «    alice_teleport: ───────X────■──┤ H ├┤M├───────────────────────»
# «                    ┌───┐     ┌─┴─┐└┬─┬┘└╥┘                       »
# «alice_entanglement: ┤ H ├──■──┤ X ├─┤M├──╫───────────|0>──────────»
# «                    └───┘  │  └───┘ └╥┘  ║                        »
# «          bob_main: ───────┼─────────╫───╫────────────────────────»
# «                           │         ║   ║                        »
# «      bob_teleport: ───────┼─────────╫───╫────────────────────────»
# «                         ┌─┴─┐       ║   ║          ┌───┐         »
# «  bob_entanglement: ─────┤ X ├───────╫───╫──────────┤ X ├─────────»
# «                         └───┘       ║   ║          └─╥─┘         »
# «                                     ║   ║ ┌──────────╨──────────┐»
# «   alice_measure: 2/═════════════════╩═══╩═╡ alice_measure_1=0x1 ╞»
# «                                     1   0 └─────────────────────┘»
# «     bob_measure: 2/══════════════════════════════════════════════»
# «                                                                  »
# «                                                                          »
# «        alice_main: ──────────────────────────────────────────────────────»
# «                                                                          »
# «    alice_teleport: ──────────────────────────────────────────────────────»
# «                                                        ┌───┐             »
# «alice_entanglement: ────────────────────────────────────┤ X ├─────────────»
# «                                                        └─┬─┘             »
# «          bob_main: ────────────────────────────X─────────┼───────────────»
# «                                                │         │       ┌───┐┌─┐»
# «      bob_teleport: ────────────────────────X───X─────────┼────■──┤ H ├┤M├»
# «                             ┌───┐          │      ┌───┐  │  ┌─┴─┐└┬─┬┘└╥┘»
# «  bob_entanglement: ─────────┤ Z ├──────────X──|0>─┤ H ├──■──┤ X ├─┤M├──╫─»
# «                             └─╥─┘                 └───┘     └───┘ └╥┘  ║ »
# «                    ┌──────────╨──────────┐                         ║   ║ »
# «   alice_measure: 2/╡ alice_measure_0=0x1 ╞═════════════════════════╬═══╬═»
# «                    └─────────────────────┘                         ║   ║ »
# «     bob_measure: 2/════════════════════════════════════════════════╩═══╩═»
# «                                                                    1   0 »
# «                                                                           »
# «        alice_main: ────────────────────────────────────────────────────X──»
# «                                                                        │  »
# «    alice_teleport: ────────────────────────────────────────────────X───X──»
# «                            ┌───┐                     ┌───┐         │      »
# «alice_entanglement: ────────┤ X ├─────────────────────┤ Z ├─────────X──|0>─»
# «                            └─╥─┘                     └─╥─┘                »
# «          bob_main: ──────────╫─────────────────────────╫──────────────────»
# «                              ║                         ║                  »
# «      bob_teleport: ──────────╫───────────|0>───────────╫──────────────────»
# «                              ║                         ║                  »
# «  bob_entanglement: ──────────╫───────────|0>───────────╫──────────────────»
# «                              ║                         ║                  »
# «   alice_measure: 2/══════════╬═════════════════════════╬══════════════════»
# «                    ┌─────────╨─────────┐     ┌─────────╨─────────┐        »
# «     bob_measure: 2/╡ bob_measure_1=0x1 ╞═════╡ bob_measure_0=0x1 ╞════════»
# «                    └───────────────────┘     └───────────────────┘        »
# «
# «        alice_main: ─────
# «
# «    alice_teleport: ─|0>─
# «
# «alice_entanglement: ─────
# «
# «          bob_main: ─────
# «
# «      bob_teleport: ─────
# «
# «  bob_entanglement: ─────
# «
# «   alice_measure: 2/═════
# «
# «     bob_measure: 2/═════
# «
