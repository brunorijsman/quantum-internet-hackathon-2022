# %%
from quantum_computer import Method
from qft import DistributedQFT

# %%
nr_processors = 2
total_nr_qubits = 4

# %%
qft = DistributedQFT(nr_processors, total_nr_qubits, Method.TELEPORT)

# %%
display(qft.circuit_diagram())

# %%
input = 3

# %%
qft.run(input)

# %%
display(qft.circuit_diagram(with_input=True))
