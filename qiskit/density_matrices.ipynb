# %%
from numpy import pi
from qiskit import QuantumCircuit, Aer
from qiskit.quantum_info import DensityMatrix
from qiskit.visualization import plot_bloch_multivector, plot_state_city
from qiskit_textbook.tools import array_to_latex

# %%
def show_state(qc):
    display(qc.draw())
    sim = Aer.get_backend("aer_simulator")
    qc.save_statevector()
    result = statevector = sim.run(qc).result()
    statevector = result.get_statevector()
    display(plot_state_city(statevector))
    density_matrix = DensityMatrix(statevector)
    print("Density matrix = ", density_matrix.data)
    display(plot_bloch_multivector(statevector))
    array_to_latex(statevector, pretext="\\text{Statevector} = ")
    None

# %% [markdown]
# Density matrix for state $\ket{0}$

# %%
qc = QuantumCircuit(1)
show_state(qc)
# Out:
# Density matrix =  [[1.+0.j 0.+0.j]
#  [0.+0.j 0.+0.j]]
# $\displaystyle
# \text{Statevector} = \begin{bmatrix}
# 1 \\
# 0
# \end{bmatrix}
# $

# %% [markdown]
# Density matrix for state $\ket{+}$

# %%
qc = QuantumCircuit(1)
qc.h(0)
show_state(qc)
# Out:
# Density matrix =  [[0.5+0.j 0.5+0.j]
#  [0.5+0.j 0.5+0.j]]
# $\displaystyle
# \text{Statevector} = \begin{bmatrix}
# \tfrac{1}{\sqrt{2}} \\
# \tfrac{1}{\sqrt{2}}
# \end{bmatrix}
# $

# %% [markdown]
# Density matrix for state $\ket{\Phi^{+}}$

# %%
qc = QuantumCircuit(2)
qc.h(0)
qc.cnot(0, 1)
show_state(qc)
# Out:
# Density matrix =  [[0.5+0.j 0. +0.j 0. +0.j 0.5+0.j]
#  [0. +0.j 0. +0.j 0. +0.j 0. +0.j]
#  [0. +0.j 0. +0.j 0. +0.j 0. +0.j]
#  [0.5+0.j 0. +0.j 0. +0.j 0.5+0.j]]
# $\displaystyle
# \text{Statevector} = \begin{bmatrix}
# \tfrac{1}{\sqrt{2}} \\
# 0 \\
# 0 \\
# \tfrac{1}{\sqrt{2}}
# \end{bmatrix}
# $

# %% [markdown]
# Density matrix for state $\ket{\Psi^{+}}$

# %%
qc = QuantumCircuit(2)
qc.h(0)
qc.cnot(0, 1)
qc.x(0)
show_state(qc)
# Out:
# Density matrix =  [[0. +0.j 0. +0.j 0. +0.j 0. +0.j]
#  [0. +0.j 0.5+0.j 0.5+0.j 0. +0.j]
#  [0. +0.j 0.5+0.j 0.5+0.j 0. +0.j]
#  [0. +0.j 0. +0.j 0. +0.j 0. +0.j]]
# $\displaystyle
# \text{Statevector} = \begin{bmatrix}
# 0 \\
# \tfrac{1}{\sqrt{2}} \\
# \tfrac{1}{\sqrt{2}} \\
# 0
# \end{bmatrix}
# $
