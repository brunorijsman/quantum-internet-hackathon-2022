# %%
from cluster import EntanglementExampleCluster, Cluster, TeleportExampleCluster
from cluster import LocalControlledPhaseExampleCluster
from utils import density_matrix_pretty_print

# %%
nr_processors = 2
total_nr_qubits = 4

# %%
cluster = Cluster(nr_processors, total_nr_qubits)

# %%
display(cluster.circuit_diagram())

# %%
example = EntanglementExampleCluster()
display(example.circuit_diagram())

# %%
example = TeleportExampleCluster()
display(example.circuit_diagram())

# %%
example = LocalControlledPhaseExampleCluster()
display(example.circuit_diagram())
