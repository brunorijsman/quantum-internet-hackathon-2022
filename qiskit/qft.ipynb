# %%
from qft import QFT
from utils import density_matrix_pretty_print

# %%
n = 3

# %%
qft = QFT(n=n, swaps=True)

# %%
display(qft.circuit_diagram())

# %%
input = 3

# %%
qft.run(input)

# %%
display(qft.circuit_diagram(with_input=True))

# %%
qft.statevector_latex()
# Out:
# $\displaystyle
# \begin{bmatrix}
# \tfrac{1}{\sqrt{8}} \\
# \tfrac{1}{4}(-1 + i) \\
# -\tfrac{1}{\sqrt{8}}i \\
# \tfrac{1}{4}(1 + i) \\
# -\tfrac{1}{\sqrt{8}} \\
# \tfrac{1}{4}(1 - i) \\
# \tfrac{1}{\sqrt{8}}i \\
# \tfrac{1}{4}(-1 - i)
# \end{bmatrix}
# $

# %%
qft.bloch_multivector()

# %%
density_matrix_pretty_print(qft.density_matrix())
# Out:
#  0.125  0.000j    -0.088 -0.088j    -0.000  0.125j     0.088 -0.088j    -0.125  0.000j     0.088  0.088j     0.000 -0.125j    -0.088  0.088j
# -0.088  0.088j     0.125  0.000j    -0.088 -0.088j     0.000  0.125j     0.088 -0.088j    -0.125  0.000j     0.088  0.088j     0.000 -0.125j
# -0.000 -0.125j    -0.088  0.088j     0.125  0.000j    -0.088 -0.088j     0.000  0.125j     0.088 -0.088j    -0.125  0.000j     0.088  0.088j
#  0.088  0.088j     0.000 -0.125j    -0.088  0.088j     0.125  0.000j    -0.088 -0.088j     0.000  0.125j     0.088 -0.088j    -0.125  0.000j
# -0.125  0.000j     0.088  0.088j     0.000 -0.125j    -0.088  0.088j     0.125  0.000j    -0.088 -0.088j    -0.000  0.125j     0.088 -0.088j
#  0.088 -0.088j    -0.125  0.000j     0.088  0.088j     0.000 -0.125j    -0.088  0.088j     0.125  0.000j    -0.088 -0.088j     0.000  0.125j
#  0.000  0.125j     0.088 -0.088j    -0.125  0.000j     0.088  0.088j    -0.000 -0.125j    -0.088  0.088j     0.125  0.000j    -0.088 -0.088j
# -0.088 -0.088j     0.000  0.125j     0.088 -0.088j    -0.125  0.000j     0.088  0.088j     0.000 -0.125j    -0.088  0.088j     0.125  0.000j

# %%
qft.density_matrix_city()
